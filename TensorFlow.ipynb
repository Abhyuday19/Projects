# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhyuday19/Projects/blob/main/TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('file.csv')

# %%
X = pd.get_dummies(df.drop(['Churn' , 'customerID'], axis=1))
y = df['Churn'].apply(lambda x : 1 if x== 'Yes' else 0 )

# %%
X_train , X_test , y_train , y_test = train_test_split(X ,  y , test_size =2)

# %%
X_train.head()
# Out:
#       SeniorCitizen  tenure  ...  TotalCharges_999.8  TotalCharges_999.9
# 2673              0      22  ...               False               False
# 3283              0      69  ...               False               False
# 6540              0      34  ...               False               False
# 3153              0      23  ...               False               False
# 859               0      72  ...               False               False
#
# [5 rows x 6575 columns]

# %%
y_train.head()
# Out:
# 2673    1
# 3283    0
# 6540    0
# 3153    0
# 859     0
# Name: Churn, dtype: int64

# %%
from tensorflow.keras.models import Sequential , load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(units=32 , activation='relu' , input_dim=len(X_train.columns)))
model.add(Dense(units=64 , activation='relu'))
model.add(Dense(units=1 , activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss = 'binary_crossentropy' , optimizer ='sgd' , metrics = ['accuracy'])

# %%
model.fit(X_train , y_train , epochs = 200 , batch_size= 32)
# Out:
# Epoch 1/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7429 - loss: 0.5379
# Epoch 2/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7612 - loss: 0.5009
# Epoch 3/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7647 - loss: 0.4888
# Epoch 4/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7611 - loss: 0.5136
# Epoch 5/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7811 - loss: 0.4730
# Epoch 6/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7755 - loss: 0.4814
# Epoch 7/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7777 - loss: 0.4702
# Epoch 8/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7736 - loss: 0.4708
# Epoch 9/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7856 - loss: 0.4653
# Epoch 10/200
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7840 - loss: 0.4600
# Epoch 11/200
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val <0.5 else 1 for val in y_hat]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# [0, 0]

# %%
accuracy_score(y_test , y_hat)
# Out:
# 1.0
